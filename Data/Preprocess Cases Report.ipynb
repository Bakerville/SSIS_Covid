# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Cases Report.csv")

# %%
data
# Out:
#                                                  Outcome  Age  Gender  \
# 0      Resolved,80s,FEMALE,Toronto Public Health,9/24...  NaN     NaN
# 1                                               Resolved  <20    MALE
# 2                                               Resolved  20s    MALE
# 3      Resolved,20s,MALE,"Region of Waterloo, Public ...  NaN     NaN
# 4                                               Resolved  20s  FEMALE
# ...                                                  ...  ...     ...
# 28495                                           Resolved  70s  FEMALE
# 28496                                           Resolved  50s    MALE
# 28497                                           Resolved  50s  FEMALE
# 28498                                           Resolved  60s    MALE
# 28499                                           Resolved  40s    MALE
#
#                             Reporting PHU SpecimenDate CaseReported Date  \
# ...

# %%
def preprocess(row):
    li = row["Outcome"].split(",")
    index = 0
    if(len(li)>1):
        for name in row.index:
            row[name] = li[index]
            index = index + 1
    return row

# %%
data=data.apply(preprocess, axis="columns")

# %%
data
# Out:
#         Outcome  Age  Gender                       Reporting PHU  \
# 0      Resolved  80s  FEMALE               Toronto Public Health
# 1      Resolved  <20    MALE                  Peel Public Health
# 2      Resolved  20s    MALE               Lambton Public Health
# 3      Resolved  20s    MALE                 "Region of Waterloo
# 4      Resolved  20s  FEMALE                Ottawa Public Health
# ...         ...  ...     ...                                 ...
# 28495  Resolved  70s  FEMALE  York Region Public Health Services
# 28496  Resolved  50s    MALE  York Region Public Health Services
# 28497  Resolved  50s  FEMALE     Durham Region Health Department
# 28498  Resolved  60s    MALE     Durham Region Health Department
# 28499  Resolved  40s    MALE  York Region Public Health Services
#
#           SpecimenDate CaseReported Date       PHUCity TestReported Date  \
# 0            9/24/2020          2/6/2021       Toronto          2/6/2021
# ...

# %%
data.loc[data["CaseReported Date"] ==  ' Pine Ridge District Health Unit"',:]
# Out:
#         Outcome  Age  Gender Reporting PHU SpecimenDate  \
# 484    Resolved  50s  FEMALE   "Haliburton     Kawartha
# 540    Resolved  70s    MALE   "Haliburton     Kawartha
# 1185   Resolved  30s    MALE   "Haliburton     Kawartha
# 1484   Resolved  30s  FEMALE   "Haliburton     Kawartha
# 1690   Resolved  50s  FEMALE   "Haliburton     Kawartha
# ...         ...  ...     ...           ...          ...
# 28335  Resolved  60s  FEMALE   "Haliburton     Kawartha
# 28357  Resolved  70s  FEMALE   "Haliburton     Kawartha
# 28359  Resolved  60s    MALE   "Haliburton     Kawartha
# 28426  Resolved  60s  FEMALE   "Haliburton     Kawartha
# 28445  Resolved  60s  FEMALE   "Haliburton     Kawartha
#
#                        CaseReported Date    PHUCity TestReported Date  \
# 484     Pine Ridge District Health Unit"  10/1/2020         10/5/2020
# 540     Pine Ridge District Health Unit"  9/27/2020         10/4/2020
# 1185    Pine Ridge District Health Unit"  9/28/2020         10/2/2020
# ...

# %%
def specified_process(row):
    row["Reporting PHU"] = row["Reporting PHU"] +  row["SpecimenDate"] + row["CaseReported Date"]
    row["Reporting PHU"] = row["Reporting PHU"][1:-1]
    col = data.columns
    for idx in range(4,len(col)-2):
        row[row.index[idx]] =  row[row.index[idx+2]]
    row[-1] = np.nan
    row[-2] = np.nan
    return row

# %%
data.loc[data["CaseReported Date"] ==  ' Pine Ridge District Health Unit"',:]=data.loc[data["CaseReported Date"] ==  ' Pine Ridge District Health Unit"',:].apply(specified_process, axis="columns")

# %%
data
# Out:
#         Outcome  Age  Gender                       Reporting PHU  \
# 0      Resolved  80s  FEMALE               Toronto Public Health
# 1      Resolved  <20    MALE                  Peel Public Health
# 2      Resolved  20s    MALE               Lambton Public Health
# 3      Resolved  20s    MALE                 "Region of Waterloo
# 4      Resolved  20s  FEMALE                Ottawa Public Health
# ...         ...  ...     ...                                 ...
# 28495  Resolved  70s  FEMALE  York Region Public Health Services
# 28496  Resolved  50s    MALE  York Region Public Health Services
# 28497  Resolved  50s  FEMALE     Durham Region Health Department
# 28498  Resolved  60s    MALE     Durham Region Health Department
# 28499  Resolved  40s    MALE  York Region Public Health Services
#
#           SpecimenDate CaseReported Date       PHUCity TestReported Date  \
# 0            9/24/2020          2/6/2021       Toronto          2/6/2021
# ...

# %%
def specified_process_2(row):
    row["Reporting PHU"] = row["Reporting PHU"] +  row["SpecimenDate"]
    row["Reporting PHU"] = row["Reporting PHU"][1:-1]
    col = data.columns
    for idx in range(4,len(col)-1):
        row[row.index[idx]] =  row[row.index[idx+1]]
    row[-1] = np.nan
    return row

data.loc[(data["SpecimenDate"] ==  ' Frontenac and Lennox & Addington Public Health"') | (data["SpecimenDate"] ==  ' Public Health"') | (data["SpecimenDate"] ==  ' Grenville and Lanark District Health Unit"') ,:]=data.loc[(data["SpecimenDate"] ==  ' Frontenac and Lennox & Addington Public Health"') | (data["SpecimenDate"] ==  ' Public Health"') | (data["SpecimenDate"] ==  ' Grenville and Lanark District Health Unit"') ,:].apply(specified_process_2, axis="columns")

# %%
data["SpecimenDate"].unique()
# Out:
# array(['9/24/2020', '12/24/2020', '9/23/2020', '9/20/2020', '9/21/2020',
#        '12/11/2020', '9/30/2020', '9/29/2020', '10/9/2020', '10/17/2020',
#        '9/28/2020', '10/4/2020', '10/8/2020', '10/3/2020', '10/5/2020',
#        '10/6/2020', '10/7/2020', '10/1/2020', '10/2/2020', '10/16/2020',
#        nan, '9/26/2020', '9/27/2020', '10/10/2020', '9/2/2020', '',
#        '9/25/2020', '8/27/2020', '8/19/2020', '9/14/2020', '9/22/2020',
#        '10/23/2020', '9/13/2020', '8/22/2020', '9/18/2020', '9/19/2020',
#        '9/15/2020', '9/17/2020', '9/16/2020', '9/11/2020', '9/9/2020',
#        '9/12/2020', '9/4/2020', '9/10/2020', '9/7/2020', '8/20/2020',
#        '9/8/2020', '9/6/2020', '8/26/2020', '6/2/2020', '8/24/2020',
#        '9/5/2020', '9/1/2020', '8/7/2020', '9/3/2020', '8/30/2020',
#        '8/31/2020', '8/25/2020', '8/29/2020', '8/28/2020', '8/23/2020',
#        '8/11/2020', '8/17/2020', '8/9/2020', '8/18/2020', '8/21/2020',
# ...

# %%
data
# Out:
#         Outcome  Age  Gender                       Reporting PHU SpecimenDate  \
# 0      Resolved  80s  FEMALE               Toronto Public Health    9/24/2020
# 1      Resolved  <20    MALE                  Peel Public Health   12/24/2020
# 2      Resolved  20s    MALE               Lambton Public Health    9/23/2020
# 3      Resolved  20s    MALE    Region of Waterloo Public Health    9/20/2020
# 4      Resolved  20s  FEMALE                Ottawa Public Health    9/21/2020
# ...         ...  ...     ...                                 ...          ...
# 28495  Resolved  70s  FEMALE  York Region Public Health Services    2/29/2020
# 28496  Resolved  50s    MALE  York Region Public Health Services    2/28/2020
# 28497  Resolved  50s  FEMALE     Durham Region Health Department    2/28/2020
# 28498  Resolved  60s    MALE     Durham Region Health Department    2/28/2020
# 28499  Resolved  40s    MALE  York Region Public Health Services    2/29/2020
#
# ...

# %%
data.to_excel("Case_Report.xlsx", index =False)
